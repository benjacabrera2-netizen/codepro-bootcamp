# %%
print('Hola mundo')
welcome = 'Hola mundo'
print(welcome)

def getWelcomeName(input1):
    hi = 'Hola, ';
    print(hi + input1);
    # if(input1.typeOf === number) { print('Recorcholis!') } else print(hi + input1);
    

getWelcomeName('benja')

#snake_case: variables se escriben con guiones bajos sin mayusculas a diferencia del camelCase. Ejemplo: snake_case

cantidad_de_frutas = 4
fruta = 'banana'

edad = 28
     #en python este tipo de dato se llama 'Interger'
altura = 1.73
    # 'Float'
nombre = 'Benja' 
    # 'String'
feliz = True;
    # 'Boolean'

#print(edad + altura + nombre + feliz)

decimal_redonda = round(3.33333, 2)
print(decimal_redonda)
# Out:
# Hola mundo
# Hola mundo
# Hola, benja
# 3.33

# %% [markdown]
# #Reglas y Sintaxis Python
#
# ##Para nombrar variables
#
# - puede empezar con letra o _
# - palabras a no usar: def, print
# - Solo en cuanto convencion:
#     para declara let en python, se escribe en minuscula;
#     pero si se escribe en MAYUSCULA toda la variable, se conviene que es una variable constante.
#
# ##Para operadores
#
# - // = division sin decimal
#
# ##Strings
#
# - literals: (f'blabla {22}')
# - Salto de lineas: (f'Juancho.\nSancho.\nPancho')
#
# ##Otros
#
# - el metodo input <input('Descripcion de lo que le pido al usuario')> le pregunta al usuario por medio del chat box que tiene el visual o el entry en la app que debe de decir la variable
# - .typeOf = type(var)
# - convertir string a interger (o el equivalente a .toString()) se hace con <int(str)>
#
# ##Funciones
# -
# - Sintaxis <getblabla():

# %% [markdown]
# #Dia 2: Challenges 🤺
#
#
# ##Challenge 1 🤺
# - Crea 3 variables con tu nombre, edad y ciudad. Imprime en una sola línea usando print()
#
# ##Challenge 2 🤺 - 10m
# - Suma: asignar dos números en dos variables diferentes cantidad_de_manzanas y cantidad_de_naranjas. Luego sumar ambas variables en cantidad_de_frutas. Imprimir la última variable.
#
# - Resta: asignar un valor numérico a la variable frutas_vendidas. Luego, asignar la resta entre cantidad_de_frutas y frutas_vendidas a la variable frutas_restantes. Imprimir la última variable.
#
# ###Challenge 3 🤺
# - Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
#     EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."
#
# ###Challenge 4 🤺
# - Solicitar al usuario ingresar dos números y almacenarlos en dos variables. Luego, imprimir la suma de los dos números.
#
# ###Challenge 5 🤺
# - Crear una función de un proceso que se les ocurra que tenga varios pasos.
# - Ejecutar la función 3 veces.
#
# Challenge 🤺 - 10m
# - Objetivo:
#     - Escribir una función que pregunte por las características de un producto a comprar (por ejemplo, tipo, tamaño, color) e imprima un resumen de ese producto con las características ingresadas.
#     - Además, deben trabajar con variables locales y globales.

# %%
#Challenge 1

edad = '27'
ciudad = 'Luque'

print(nombre + ' ' + edad + ' ' + ciudad)
print(nombre, '  ', edad, '  ', ciudad)
print(f'Mi nombre es {nombre}, mi edad es {edad} y vivo en {ciudad}.')

ciudad = 'Luque'
var = type(ciudad)
print(var)
# Out:
# Benja 27 Luque
# Benja    27    Luque
# Mi nombre es Benja, mi edad es 27 y vivo en Luque.
# <class 'str'>

# %%
#Challenge 2

##Suma

###Variables declaradas
cantidad_de_manzanas = 2
cantidad_de_naranjas = 4
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas

###Log de Consola
print(f'La cantidad de frutas en total son: {cantidad_de_frutas}');


##Resta

###Variables declaradas
frutas_vendidas = 1
frutas_restantes = cantidad_de_frutas  - frutas_vendidas

###Log de Consola
print(f'La cantidad de frutas despues de la venta son: {frutas_restantes}');
# Out:
# La cantidad de frutas en total son: 6
# La cantidad de frutas despues de la venta son: 5

# %%
#Challenge 3
nombre_compa1 = 'Alan Lezcano'
nombre_compa2 = 'Lucas Gimenez'

print(f'Hola {nombre_compa1} y {nombre_compa2}. Me llamo {nombre}. Mucho gusto.');

print('\n')

##Solucion de otro compa
print(f'Hola {nombre_compa1} y {nombre_compa2}.\nMe llamo {nombre}.\nMucho gusto!');
# Out:
# Hola Alan Lezcano y Lucas Gimenez. Me llamo Benja. Mucho gusto.
#
#
# Hola Alan Lezcano y Lucas Gimenez.
# Me llamo Benja.
# Mucho gusto.

# %%
empanada = input('Que sabor de empanada quieres')
print(f'al kp le gusta la empa sabor {empanada}')
# Out:
# al kp le gusta la empa sabor camion

# %%
#Challenge 4

##Declaracion de variables
int1 = round(float(input('numero1')))
int2 = round(float(input('escribir segundo numero')))
var_print = int1 + int2

##Log de consola
print(f'El valor de la suma es {var_print}')
# Out:
# El valor de la suma es 5

# %%
def getFlirtBot():
    response = input('salu2 o captcha')

    print(f'Hola {response}, como estas beyura?')
    response2 = input('respuesta al flirt')
    print(f'sabia que estarias {response2}, voy a hacer algo para que estes mejor.')
    bot_calculation = 2 + 2
    print('Te sumo 2 mas 2 para que tu dia sea mejor, me lo agradeces mas tarde')
    return 4

getWelcomeBot()
# Out:
# Hola siu, como estas beyura?
# Asi me gusta, sabia que estarias siuu
# Te sumo 2 mas 2 para que tu dia sea mejor, me lo agradeces mas tarde {name}
# 4

# %%
def get_renaming_bot():
    name1 = input('Tu nombre')
    print(f'Hola beyura, escuche que te llaman {name1}!')
    print(f'Te llamare Kambuchi.')
    print(f'Me debes $10. Me lo puedes pagar en 12 comodas cuotas\n...\ne intereses.')

get_renaming_bot()
get_renaming_bot()
get_renaming_bot()
# Out:
# Hola beyura, escuche que te llaman Pablito!
# Te llamare Kambuchi.
# Me debes $10. Me lo puedes pagar en 12 comodas cuotas
# ...
# e intereses.
# Hola beyura, escuche que te llaman Pablo!
# Te llamare Kambuchi.
# Me debes $10. Me lo puedes pagar en 12 comodas cuotas
# ...
# e intereses.
# Hola beyura, escuche que te llaman Paul!
# Te llamare Kambuchi.
# Me debes $10. Me lo puedes pagar en 12 comodas cuotas
# ...
# e intereses.

# %%
#Challenge 6

def get_elem_buy(prod):
    elements = input('caracteristicas del producto')
    response= f'El producto es {prod} y posee: {elements}'
    print(response)

get_elem_buy('torta')
# Out:
# El producto es torta y posee: Chocolate

# %%
bot_calculation = 2 + 2
pancho = 'Francisco'

def get_flirt_bot2(input1):
    type_a = type(input1)

    if type_a == 'str':
        print(f'Sucumbiras ante el poder del captcha!')
    else:
        print(f'Hola {input1}, como estas beyura?')
        response2 = input('respuesta al flirt')
        print(f'Sabia que estarias {response2}, voy a hacer algo para que estes mejor.')
        print('Te sumo 2 mas 2 para que tu dia sea mejor, me lo agradeces despues:')
        print(bot_calculation)


get_flirt_bot2(pancho)
# Out:
# Hola Francisco, como estas beyura?
# Sabia que estarias todo bom, voy a hacer algo para que estes mejor.
# Te sumo 2 mas 2 para que tu dia sea mejor, me lo agradeces despues:
# 4
